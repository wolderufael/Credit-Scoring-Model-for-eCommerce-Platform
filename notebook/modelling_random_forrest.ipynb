# %% [markdown]
# # Modelling

# %% [markdown]
# ### Adding project directory to system path

# %%
import pandas as pd
import os
notebook_dir = os.getcwd()
parent_path=os.path.dirname(notebook_dir)

os.chdir(parent_path)

# %% [markdown]
# ### Importing modules

# %%
from script.default_estimator_and_WoE_binning import Estimator

# %% [markdown]
# ### Instantiate class

# %%
modelling=Estimator()

# %% [markdown]
# ### Load data

# %%
train_data=pd.read_csv("data/train_data.csv")
test_data=pd.read_csv("data/test_data.csv")

# %% [markdown]
# ## Prediction using Random Forrest

# %%
lr,lr_model,train_pred,test_pred,y_train,y_test,X_test=modelling.predict_risk_random_forrest(train_data,test_data)
# Out:
# Feature Importances: [5.89177309e-03 5.69254208e-02 1.36502283e-01 5.38948509e-01
#  1.44002868e-01 6.28542311e-02 4.50785986e-02 2.65007099e-03
#  4.22712678e-03 1.42004802e-03 3.01617425e-04 4.38327493e-04
#  7.59127001e-04]

# %% [markdown]
# ## Performanc ks and ROC

# %%
train_perf,test_perf=modelling.performance_ks_roc(train_pred,test_pred,y_train,y_test)

# %% [markdown]
# ## Evaluation

# %%
predictions=modelling.evaluation(lr,X_test,y_test)
# Out:
# Accuracy
# 1.0
# AUC Score
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     26399
#            1       1.00      1.00      1.00      2299
#
#     accuracy                           1.00     28698
#    macro avg       1.00      1.00      1.00     28698
# weighted avg       1.00      1.00      1.00     28698

# %% [markdown]
# ## Confusion matrix

# %%
modelling.confusion_matrix(y_test,predictions)

# %% [markdown]
# ## Save model

# %%
modelling.save_model_with_timestamp(lr_model,'random_forrest_model')
# Out:
# Model saved as models/random_forrest_model-09-10-2024-04-19-53-00.pkl
# 'models/random_forrest_model-09-10-2024-04-19-53-00.pkl'
