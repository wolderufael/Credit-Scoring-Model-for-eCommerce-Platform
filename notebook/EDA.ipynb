# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Adding project directory to system path

# %%
import pandas as pd
import os
notebook_dir = os.getcwd()
parent_path=os.path.dirname(notebook_dir)

os.chdir(parent_path)

# %% [markdown]
# ### Importing modules

# %%
from script.EDA import EDA

# %% [markdown]
# ### Loading the data

# %%
data=pd.read_csv("data/data.csv")
data.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %% [markdown]
# ### Instantiate class

# %%
eda= EDA()

# %% [markdown]
# ## Overview of the Data
# Understand the structure of the dataset, including the number of rows, columns, and data types.

# %%
eda.data_overview(data)
# Out:
# Number of rows:95662
# Number of columns:16
# Data types of each column:
# TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object

# %% [markdown]
# ## Summary Statistics
# Understand the central tendency, dispersion, and shape of the dataset’s distribution.

# %%
eda.summarize_dataset(data)
# Out:
#                Mean  Median    Mode  Standard Deviation      Variance  \
# Amount  6717.846433  1000.0  1000.0       123306.797164  1.520457e+10
# Value   9900.583941  1000.0  1000.0       123122.087776  1.515905e+10
#
#              Range     IQR   Skewness     Kurtosis
# Amount  10880000.0  2850.0  51.098490  3363.127739
# Value    9879998.0  4725.0  51.291086  3378.069274

# %% [markdown]
# ## Distribution of Numerical Features
# Visualizing the distribution of numerical features to identify patterns, skewness, and potential outliers.In our case numerical features are **'Amount'** and **'Value'**

# %%
eda.plot_numerical_distributions(data)

# %%
(data['Amount'].min(), data['Amount'].max())
# Out:
# (np.float64(-1000000.0), np.float64(9880000.0))

# %% [markdown]
# ## Distribution of Categorical Features
# Analyzing the distribution of categorical features provides insights into the frequency and variability of categories.In our case catagorical features are **'ProviderId'**,**'ProductId'**,**'ProductCategory'**,**'ChannelId'**,**'PricingStrategy'** and **'FraudResult'**

# %%
eda.plot_categorical_distributions(data)

# %% [markdown]
# ## Identifying Missing Values
# Identifying missing values to determine missing data and decide on appropriate imputation strategies.

# %%
eda.check_missing_value(data)
# Out:
# There is no missing value in the data

# %% [markdown]
# ## Outlier Detection
# Using box plots to identify outliers.How Outliers are Determined
# 1. **Box:**
#
# The box itself represents the interquartile range (IQR), which is the range between the first (Q1) and third quartiles (Q3).
# The line inside the box indicates the median (Q2).
#
# 2. **Whiskers:**
#
# The whiskers extend from the box to the smallest and largest values within 1.5 times the IQR from Q1 and Q3, respectively.
# The whiskers do not extend to the outliers.
# Outliers are defined based on the IQR:
#
# **Lower Bound**: 𝑄1−1.5×IQR
#
# **Upper Bound**: Q3+1.5×IQR
#
# 3. **Outliers:**
#
# Any data points that fall outside of the whiskers are considered outliers.
# These outliers are typically marked with individual points, often shown as circles ('o').

# %%
eda.plot_outliers_boxplots(data)
